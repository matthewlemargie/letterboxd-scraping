# %%
from bs4 import BeautifulSoup
import time
import requests

# %%
page = requests.get("https://letterboxd.com/film/barbie/")

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
stars = soup.find_all("li")
stars
# Out:
# [<li><a href="/list/new/">Start a new list…</a></li>,
#  <li><a class="js-add-all-films-on-page-to-list" href="#">Add all films to a list…</a></li>,
#  <li><a class="js-add-all-films-on-page-to-watchlist" data-action="/watchlist/add-films/" href="#">Add all films to watchlist</a></li>,
#  <li class="stat"><a class="has-icon icon-placeholder"> </a></li>,
#  <li><a data-id="cast" href="/film/barbie/">Cast</a></li>,
#  <li><a data-id="crew" href="/film/barbie/crew/" id="crew">Crew</a></li>,
#  <li><a data-id="details" href="/film/barbie/details/">Details</a></li>,
#  <li><a data-id="genres" href="/film/barbie/genres/">Genres</a></li>,
#  <li><a data-id="releases" href="/film/barbie/releases/">Releases</a></li>,
#  <li class="smenu-subselected"><span class="selected">Date</span></li>,
#  <li><a class="item js-switch-tabbed-nav" data-id="releases-by-country" data-parent-id="releases" href="/film/barbie/releases/by/country/">Country</a></li>,
#  <li class="listitem">
# ...
